# %% [markdown]
# <a href="https://colab.research.google.com/github/pauloestevao0/atmo_teste/blob/main/python/CSGO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mysql.connector
# !pip install pandas
# !pip install datetime
# !pip install logging
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 11.9 MB 5.0 MB/s
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp37-cp37m-linux_x86_64.whl size=247965 sha256=09447f729cd2327bec02f3fdf9c3762dcd027b8c8d781c4991edb52b8e53d37b
#   Stored in directory: /root/.cache/pip/wheels/42/2f/c3/692fc7fc1f0d8c06b9175d94f0fc30f4f92348f5df5af1b8b7
# Successfully built mysql.connector
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 52 kB 814 kB/s
# ...
#      |████████████████████████████████| 254 kB 10.0 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 96 kB 2.4 MB/s
# ...

# %%
import mysql.connector
import pandas as pd
import datetime
import logging

start = datetime.datetime.now()

#acessando db mysql
url = "atmo-db.cncfsgdjnfjz.sa-east-1.rds.amazonaws.com"
schema = "CSGO"
usuario = "candidato"
senha = "analista_atmo"

con = mysql.connector.connect (host = url, database = schema, user = usuario, password = senha)

#querys para tabela 
players = "SELECT * FROM tb_players" 
medalha = "SELECT * FROM tb_medalha"
lobby_stats = "SELECT * FROM tb_lobby_stats_player"
players_medalhas = "SELECT * FROM tb_players_medalha"
personal_query = ""

cursor = con.cursor(named_tuple=True)
cursor.execute(players_medalhas)
result_pm = cursor.fetchall()
cursor.close()

cursor = con.cursor(named_tuple=True)
cursor.execute(players)
result_p = cursor.fetchall()
cursor.close()

cursor = con.cursor(named_tuple=True)
cursor.execute(medalha)
result_m = cursor.fetchall()
cursor.close()

cursor = con.cursor(named_tuple=True)
cursor.execute(lobby_stats)
result_lb = cursor.fetchall()
cursor.close()


df_resultado_pm = pd.DataFrame(result_pm)
df_resultado_p = pd.DataFrame(result_p)
df_resultado_m = pd.DataFrame(result_m)
df_resultado_lb = pd.DataFrame(result_lb)

#convertendo para snake_case
df_resultado_pm.columns = [s.replace('A','_a') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('B','_b') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('C','_c') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('D','_d') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('E','_e') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('F','_f') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('G','_g') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('H','_h') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('I','_i') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('J','_j') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('K','_k') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('L','_l') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('M','_m') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('N','_n') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('O','_o') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('P','_p') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('Q','_q') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('R','_r') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('S','_s') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('T','_t') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('U','_u') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('V','_v') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('W','_w') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('X','_x') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('Y','_y') for s in df_resultado_pm.columns]
df_resultado_pm.columns = [s.replace('Z','_z') for s in df_resultado_pm.columns]
df_resultado_p.columns = [s.replace('A','_a') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('B','_b') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('C','_c') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('D','_d') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('E','_e') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('F','_f') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('G','_g') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('H','_h') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('I','_i') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('J','_j') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('K','_k') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('L','_l') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('M','_m') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('N','_n') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('O','_o') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('P','_p') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('Q','_q') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('R','_r') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('S','_s') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('T','_t') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('U','_u') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('V','_v') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('W','_w') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('X','_x') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('Y','_y') for s in df_resultado_p.columns]
df_resultado_p.columns = [s.replace('Z','_z') for s in df_resultado_p.columns]
df_resultado_m.columns = [s.replace('A','_a') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('B','_b') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('C','_c') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('D','_d') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('E','_e') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('F','_f') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('G','_g') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('H','_h') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('I','_i') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('J','_j') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('K','_k') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('L','_l') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('M','_m') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('N','_n') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('O','_o') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('P','_p') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('Q','_q') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('R','_r') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('S','_s') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('T','_t') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('U','_u') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('V','_v') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('W','_w') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('X','_x') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('Y','_y') for s in df_resultado_m.columns]
df_resultado_m.columns = [s.replace('Z','_z') for s in df_resultado_m.columns]
df_resultado_lb.columns = [s.replace('A','_a') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('B','_b') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('C','_c') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('D','_d') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('E','_e') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('F','_f') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('G','_g') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('H','_h') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('I','_i') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('J','_j') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('K','_k') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('L','_l') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('M','_m') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('N','_n') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('O','_o') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('P','_p') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('Q','_q') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('R','_r') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('S','_s') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('T','_t') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('U','_u') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('V','_v') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('W','_w') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('X','_x') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('Y','_y') for s in df_resultado_lb.columns]
df_resultado_lb.columns = [s.replace('Z','_z') for s in df_resultado_lb.columns]

def show_tables():
  display(df_resultado_pm)
  display(df_resultado_p)
  display(df_resultado_m)
  display(df_resultado_lb)

def export_tables():
#exportando arquivos para CSV
  df_resultado_pm.to_csv(r'C:\Users\Public\Downloads\player_medals.csv', index=False)
  df_resultado_p.to_csv(r'C:\Users\Public\Downloads\players.csv', index=False)
  df_resultado_m.to_csv(r'C:\Users\Public\Downloads\medals.csv', index=False)
  df_resultado_lb.to_csv(r'C:\Users\Public\Downloads\lobbystats.csv', index=False)

def main():
  print("Inicializando o processo de captura de dados - {}".format(start))
  print("Processo finalizado com sucesso - {}".format(datetime.datetime.now()))
  cursor.close()
  con.close()
  show_tables()
  export_tables()



main()
# Out:
# Inicializando o processo de captura de dados - 2022-11-13 18:17:04.422529
#           id  id_player  id_medal dt_created_at dt_expiration   dt_remove  \
# 0          1       1982         1    2018-10-04    2016-07-23  2016-07-24
# 1          2       1982         1    2018-12-12    2017-01-11  2017-01-12
# 2          3       1982         1    2019-01-08    2017-03-16  2017-03-17
# 3          4       1982         1    2018-12-09    2017-09-10  2017-09-11
# 4          5       1982         1    2018-10-04    2018-03-19  2018-03-20
# ...      ...        ...       ...           ...           ...         ...
# 32695  26407       1478        32    2020-03-16          None        None
# 32696  26630        431        32    2020-02-16          None        None
# 32697  26704       2326        32    2020-03-13          None        None
# 32698  26810       1657        32    2019-11-07          None        None
# 32699  26911       1463        32    2019-11-08          None        None
#
# ...
